# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %% [markdown]
# """
# 🤖 Understanding ReLU & Sigmoid (Super Simple Explanation for a 10-Year-Old)
#
# Imagine you are teaching a robot to understand numbers and make decisions.
# The robot processes numbers using special switches called activation functions.
# Two important ones are:
#
# 1️⃣ ReLU (Rectified Linear Unit) → Helps the robot stay positive
# 2️⃣ Sigmoid → Helps the robot decide between two choices
#
# ------------------------------------------------------------
# 🔹 ReLU (Rectified Linear Unit)
# ------------------------------------------------------------
# 💡 What is it?
# - If the number is positive, keep it the same.
# - If the number is negative, change it to zero.
#
# 📌 Simple Rule:
#     ReLU(x) = max(0, x)
#
# ✅ Example:
#     Input    | ReLU Output
#     ----------------------
#       5      | 5
#      -3      | 0
#      10      | 10
#      -7      | 0
#
# 🚀 Why Use ReLU?
# - It helps the model focus only on important (positive) signals.
# - It makes learning faster and more efficient.
#
# 🧠 Think of it like a broken calculator that only shows numbers 0 or bigger.
#    If you type -5, it just says 0! 😆
#
# ------------------------------------------------------------
# 🔹 Sigmoid (For Yes/No Decisions)
# ------------------------------------------------------------
# 💡 What is it?
# - Takes any number and squishes it between 0 and 1.
# - If the output is close to 1, it means YES (e.g., "Sweet Chocolate 🍫").
# - If the output is close to 0, it means NO (e.g., "Bitter Chocolate 🏴").
#
# 📌 Simple Rule:
#     Sigmoid(x) = 1 / (1 + e^(-x))
#
# ✅ Example:
#     Input    | Sigmoid Output (Probability) | Meaning
#     ---------------------------------------
#       5      | 0.99                         | Almost YES ✅
#      -3      | 0.05                         | Almost NO ❌
#       0      | 0.50                         | Maybe 🤔
#      10      | 0.999                        | Definitely YES 🚀
#
# 🚀 Why Use Sigmoid?
# - It's perfect for binary classification (Yes/No, Sweet/Bitter, 0/1).
# - It gives a probability score between 0 and 1.
#
# 🧠 Think of it like a magic ball 🎱 that gives answers between 0% (No) and 100% (Yes).
#
# """

# %%
diabetes_data = pd.read_csv('diabetes_prediction_dataset.csv')

# %%
diabetes_data.shape
# Out:
# (100000, 9)

# %%
diabetes_data.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
diabetes_data.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
data = diabetes_data.drop(['gender'],axis = 1)

# %%
data.head()
# Out:
#     age  hypertension  heart_disease smoking_history    bmi  HbA1c_level  \
# 0  80.0             0              1           never  25.19          6.6
# 1  54.0             0              0         No Info  27.32          6.6
# 2  28.0             0              0           never  27.32          5.7
# 3  36.0             0              0         current  23.45          5.0
# 4  76.0             1              1         current  20.14          4.8
#
#    blood_glucose_level  diabetes
# 0                  140         0
# 1                   80         0
# 2                  158         0
# 3                  155         0
# 4                  155         0

# %%
dia_bete = data.drop(['smoking_history'], axis = 1)

# %%
dia_bete.head()
# Out:
#     age  hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level  \
# 0  80.0             0              1  25.19          6.6                  140
# 1  54.0             0              0  27.32          6.6                   80
# 2  28.0             0              0  27.32          5.7                  158
# 3  36.0             0              0  23.45          5.0                  155
# 4  76.0             1              1  20.14          4.8                  155
#
#    diabetes
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
x = dia_bete.drop(columns = 'diabetes', axis = 1)
y = dia_bete['diabetes']

# %%
print(x)
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level
# 0                      140
# 1                       80
# 2                      158
# 3                      155
# 4                      155
# ...                    ...
# 99995                   90
# 99996                  100
# 99997                  155
# 99998                  100
# 99999                   90
#
# [100000 rows x 6 columns]

# %%
print(y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((80000, 6), (20000, 6), (80000,), (20000,))

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# normalising data values using standard scaler so that all features have  a mean of 0 and a standard deviation of 1.

# %%
X_test
# Out:
# array([[-1.28824683e+00, -2.86309234e-01, -2.03558690e-01,
#         -9.83570464e-01,  2.55560889e-01, -2.95858589e-01],
#        [-1.73274126e+00, -2.86309234e-01, -2.03558690e-01,
#         -9.56361028e-01, -4.91573701e-01,  1.70590592e-01],
#        [ 9.34225330e-01, -2.86309234e-01, -2.03558690e-01,
#         -3.03334543e-01, -1.89245106e+00,  1.52083822e+00],
#        ...,
#        [ 3.11933125e-01, -2.86309234e-01, -2.03558690e-01,
#         -1.23449933e-01, -6.78357348e-01, -9.34157469e-01],
#        [ 1.37871976e+00, -2.86309234e-01,  4.91258810e+00,
#         -1.00746719e-03,  1.00269548e+00, -9.34157469e-01],
#        [ 4.52364651e-02, -2.86309234e-01, -2.03558690e-01,
#         -5.24033309e-01,  2.55560889e-01,  1.70590592e-01]])

# %%
X_train
# Out:
# array([[ 1.37871976e+00, -2.86309234e-01, -2.03558690e-01,
#         -3.86474489e-01, -1.89245106e+00, -1.42515661e+00],
#        [ 1.68986587e+00, -2.86309234e-01, -2.03558690e-01,
#         -4.12172291e-01,  1.62169065e-01,  1.70590592e-01],
#        [-1.77010751e-01, -2.86309234e-01, -2.03558690e-01,
#         -4.52986446e-01, -1.42549194e+00,  4.89740032e-01],
#        ...,
#        [ 7.87021842e-04, -2.86309234e-01, -2.03558690e-01,
#         -1.79380442e-01,  2.55560889e-01, -1.30240682e+00],
#        [-2.21460194e-01, -2.86309234e-01, -2.03558690e-01,
#         -3.57753417e-01,  6.29128183e-01,  4.89740032e-01],
#        [-8.43752400e-01, -2.86309234e-01, -2.03558690e-01,
#          1.00272103e-01, -4.91573701e-01,  5.14289989e-01]])

# %%
mlp = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=l2(0.001)),
    Dropout(0.3),  # Prevent overfitting
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(16, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(1, activation='sigmoid')  # Binary classification output
])

# %%
mlp.compile(optimizer=Adam(learning_rate=0.0005), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# - The model needs instructions on how to learn and improve.
# - Compilation sets up the learning process by choosing:
#   - An optimizer (how to adjust weights)
#   - A loss function (how to measure mistakes)
#   - Performance metrics (how well it's learning)
#
# - **optimizer=Adam(learning_rate=0.0005)** → Adam optimizer adjusts weights to minimize errors.
# - **loss='binary_crossentropy'** → Used for classification with two possible outcomes (0 or 1).
# - **metrics=['accuracy']** → Measures how often the model makes correct predictions.
#
# Think of it like setting up training rules for an athlete! The optimizer is the coach, the loss function is feedback on mistakes, and accuracy is the scoreboard

# %%
mlp.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.2094 - accuracy: 0.9538 - val_loss: 0.1426 - val_accuracy: 0.9644
# Epoch 2/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1328 - accuracy: 0.9649 - val_loss: 0.1224 - val_accuracy: 0.9676
# Epoch 3/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1196 - accuracy: 0.9668 - val_loss: 0.1141 - val_accuracy: 0.9678
# Epoch 4/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1144 - accuracy: 0.9683 - val_loss: 0.1095 - val_accuracy: 0.9700
# Epoch 5/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1110 - accuracy: 0.9689 - val_loss: 0.1073 - val_accuracy: 0.9700
# Epoch 6/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1085 - accuracy: 0.9695 - val_loss: 0.1054 - val_accuracy: 0.9702
# Epoch 7/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1066 - accuracy: 0.9699 - val_loss: 0.1042 - val_accuracy: 0.9708
# Epoch 8/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1057 - accuracy: 0.9701 - val_loss: 0.1036 - val_accuracy: 0.9711
# Epoch 9/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1048 - accuracy: 0.9701 - val_loss: 0.1037 - val_accuracy: 0.9704
# Epoch 10/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1037 - accuracy: 0.9703 - val_loss: 0.1050 - val_accuracy: 0.9679
# Epoch 11/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1030 - accuracy: 0.9704 - val_loss: 0.1003 - val_accuracy: 0.9712
# Epoch 12/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1026 - accuracy: 0.9705 - val_loss: 0.0995 - val_accuracy: 0.9714
# Epoch 13/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1020 - accuracy: 0.9705 - val_loss: 0.0996 - val_accuracy: 0.9718
# Epoch 14/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1018 - accuracy: 0.9706 - val_loss: 0.1005 - val_accuracy: 0.9693
# Epoch 15/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1016 - accuracy: 0.9707 - val_loss: 0.0990 - val_accuracy: 0.9698
# Epoch 16/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1014 - accuracy: 0.9707 - val_loss: 0.0991 - val_accuracy: 0.9715
# Epoch 17/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1010 - accuracy: 0.9704 - val_loss: 0.1006 - val_accuracy: 0.9705
# Epoch 18/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1014 - accuracy: 0.9707 - val_loss: 0.0991 - val_accuracy: 0.9707
# Epoch 19/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1006 - accuracy: 0.9708 - val_loss: 0.0976 - val_accuracy: 0.9718
# Epoch 20/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1006 - accuracy: 0.9710 - val_loss: 0.0994 - val_accuracy: 0.9714
# Epoch 21/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1004 - accuracy: 0.9708 - val_loss: 0.0980 - val_accuracy: 0.9715
# Epoch 22/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1004 - accuracy: 0.9707 - val_loss: 0.0979 - val_accuracy: 0.9715
# Epoch 23/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1001 - accuracy: 0.9707 - val_loss: 0.0975 - val_accuracy: 0.9716
# Epoch 24/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1000 - accuracy: 0.9710 - val_loss: 0.1077 - val_accuracy: 0.9657
# Epoch 25/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.1002 - accuracy: 0.9710 - val_loss: 0.0984 - val_accuracy: 0.9713
# Epoch 26/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0998 - accuracy: 0.9708 - val_loss: 0.0990 - val_accuracy: 0.9717
# Epoch 27/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0996 - accuracy: 0.9710 - val_loss: 0.0972 - val_accuracy: 0.9718
# Epoch 28/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0992 - accuracy: 0.9710 - val_loss: 0.0974 - val_accuracy: 0.9716
# Epoch 29/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0995 - accuracy: 0.9710 - val_loss: 0.0972 - val_accuracy: 0.9711
# Epoch 30/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0993 - accuracy: 0.9710 - val_loss: 0.0969 - val_accuracy: 0.9712
# Epoch 31/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0992 - accuracy: 0.9710 - val_loss: 0.0961 - val_accuracy: 0.9714
# Epoch 32/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0991 - accuracy: 0.9710 - val_loss: 0.0988 - val_accuracy: 0.9719
# Epoch 33/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0994 - accuracy: 0.9708 - val_loss: 0.0982 - val_accuracy: 0.9719
# Epoch 34/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0992 - accuracy: 0.9707 - val_loss: 0.0970 - val_accuracy: 0.9714
# Epoch 35/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0990 - accuracy: 0.9708 - val_loss: 0.0986 - val_accuracy: 0.9711
# Epoch 36/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0988 - accuracy: 0.9707 - val_loss: 0.0956 - val_accuracy: 0.9720
# Epoch 37/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0991 - accuracy: 0.9711 - val_loss: 0.0969 - val_accuracy: 0.9714
# Epoch 38/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0990 - accuracy: 0.9709 - val_loss: 0.0956 - val_accuracy: 0.9714
# Epoch 39/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0992 - accuracy: 0.9710 - val_loss: 0.0958 - val_accuracy: 0.9717
# Epoch 40/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0989 - accuracy: 0.9710 - val_loss: 0.0955 - val_accuracy: 0.9719
# Epoch 41/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0987 - accuracy: 0.9708 - val_loss: 0.0955 - val_accuracy: 0.9718
# Epoch 42/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0989 - accuracy: 0.9710 - val_loss: 0.0966 - val_accuracy: 0.9706
# Epoch 43/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0987 - accuracy: 0.9710 - val_loss: 0.0961 - val_accuracy: 0.9718
# Epoch 44/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0984 - accuracy: 0.9709 - val_loss: 0.0971 - val_accuracy: 0.9714
# Epoch 45/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0988 - accuracy: 0.9710 - val_loss: 0.0956 - val_accuracy: 0.9719
# Epoch 46/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0982 - accuracy: 0.9709 - val_loss: 0.0964 - val_accuracy: 0.9719
# Epoch 47/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0985 - accuracy: 0.9709 - val_loss: 0.0961 - val_accuracy: 0.9715
# Epoch 48/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0986 - accuracy: 0.9708 - val_loss: 0.0950 - val_accuracy: 0.9718
# Epoch 49/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0987 - accuracy: 0.9710 - val_loss: 0.1003 - val_accuracy: 0.9714
# Epoch 50/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0982 - accuracy: 0.9710 - val_loss: 0.0950 - val_accuracy: 0.9718
# Epoch 51/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0978 - accuracy: 0.9709 - val_loss: 0.0954 - val_accuracy: 0.9718
# Epoch 52/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0984 - accuracy: 0.9710 - val_loss: 0.0952 - val_accuracy: 0.9715
# Epoch 53/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0982 - accuracy: 0.9710 - val_loss: 0.0956 - val_accuracy: 0.9711
# Epoch 54/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0981 - accuracy: 0.9711 - val_loss: 0.0961 - val_accuracy: 0.9715
# Epoch 55/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0980 - accuracy: 0.9711 - val_loss: 0.0950 - val_accuracy: 0.9718
# Epoch 56/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0981 - accuracy: 0.9709 - val_loss: 0.0955 - val_accuracy: 0.9717
# Epoch 57/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0981 - accuracy: 0.9711 - val_loss: 0.0941 - val_accuracy: 0.9719
# Epoch 58/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0980 - accuracy: 0.9711 - val_loss: 0.0976 - val_accuracy: 0.9715
# Epoch 59/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0983 - accuracy: 0.9711 - val_loss: 0.0966 - val_accuracy: 0.9711
# Epoch 60/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0981 - accuracy: 0.9711 - val_loss: 0.0960 - val_accuracy: 0.9719
# Epoch 61/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0976 - accuracy: 0.9710 - val_loss: 0.0953 - val_accuracy: 0.9711
# Epoch 62/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0980 - accuracy: 0.9708 - val_loss: 0.0984 - val_accuracy: 0.9715
# Epoch 63/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0978 - accuracy: 0.9710 - val_loss: 0.0950 - val_accuracy: 0.9704
# Epoch 64/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0974 - accuracy: 0.9711 - val_loss: 0.0943 - val_accuracy: 0.9717
# Epoch 65/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0979 - accuracy: 0.9709 - val_loss: 0.0987 - val_accuracy: 0.9714
# Epoch 66/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0979 - accuracy: 0.9711 - val_loss: 0.0961 - val_accuracy: 0.9714
# Epoch 67/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0977 - accuracy: 0.9709 - val_loss: 0.0954 - val_accuracy: 0.9710
# Epoch 68/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0976 - accuracy: 0.9710 - val_loss: 0.0973 - val_accuracy: 0.9718
# Epoch 69/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0977 - accuracy: 0.9711 - val_loss: 0.0945 - val_accuracy: 0.9720
# Epoch 70/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0974 - accuracy: 0.9713 - val_loss: 0.0961 - val_accuracy: 0.9718
# Epoch 71/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0977 - accuracy: 0.9709 - val_loss: 0.0945 - val_accuracy: 0.9719
# Epoch 72/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0979 - accuracy: 0.9710 - val_loss: 0.0943 - val_accuracy: 0.9718
# Epoch 73/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0973 - accuracy: 0.9712 - val_loss: 0.0947 - val_accuracy: 0.9718
# Epoch 74/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0978 - accuracy: 0.9709 - val_loss: 0.0948 - val_accuracy: 0.9716
# Epoch 75/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0980 - accuracy: 0.9708 - val_loss: 0.0954 - val_accuracy: 0.9717
# Epoch 76/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0978 - accuracy: 0.9709 - val_loss: 0.0947 - val_accuracy: 0.9718
# Epoch 77/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0975 - accuracy: 0.9708 - val_loss: 0.0943 - val_accuracy: 0.9719
# Epoch 78/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0977 - accuracy: 0.9710 - val_loss: 0.0938 - val_accuracy: 0.9720
# Epoch 79/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0973 - accuracy: 0.9711 - val_loss: 0.0950 - val_accuracy: 0.9716
# Epoch 80/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0973 - accuracy: 0.9711 - val_loss: 0.0963 - val_accuracy: 0.9715
# Epoch 81/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0975 - accuracy: 0.9711 - val_loss: 0.0945 - val_accuracy: 0.9717
# Epoch 82/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0976 - accuracy: 0.9710 - val_loss: 0.0950 - val_accuracy: 0.9719
# Epoch 83/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0977 - accuracy: 0.9711 - val_loss: 0.0963 - val_accuracy: 0.9719
# Epoch 84/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0972 - accuracy: 0.9711 - val_loss: 0.0965 - val_accuracy: 0.9698
# Epoch 85/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0975 - accuracy: 0.9706 - val_loss: 0.0977 - val_accuracy: 0.9719
# Epoch 86/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0973 - accuracy: 0.9709 - val_loss: 0.0945 - val_accuracy: 0.9717
# Epoch 87/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0971 - accuracy: 0.9711 - val_loss: 0.0945 - val_accuracy: 0.9720
# Epoch 88/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0971 - accuracy: 0.9712 - val_loss: 0.0949 - val_accuracy: 0.9716
# Epoch 89/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0973 - accuracy: 0.9710 - val_loss: 0.0943 - val_accuracy: 0.9720
# Epoch 90/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0976 - accuracy: 0.9709 - val_loss: 0.0955 - val_accuracy: 0.9717
# Epoch 91/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0972 - accuracy: 0.9711 - val_loss: 0.0958 - val_accuracy: 0.9710
# Epoch 92/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0974 - accuracy: 0.9710 - val_loss: 0.0945 - val_accuracy: 0.9717
# Epoch 93/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0970 - accuracy: 0.9712 - val_loss: 0.0943 - val_accuracy: 0.9718
# Epoch 94/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0973 - accuracy: 0.9709 - val_loss: 0.0958 - val_accuracy: 0.9718
# Epoch 95/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0970 - accuracy: 0.9712 - val_loss: 0.0989 - val_accuracy: 0.9706
# Epoch 96/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0974 - accuracy: 0.9711 - val_loss: 0.0979 - val_accuracy: 0.9711
# Epoch 97/100
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.0974 - accuracy: 0.9707 - val_loss: 0.0952 - val_accuracy: 0.9719
# Epoch 98/100
# 2500/2500 [==============================] - 5s 2ms/step - loss: 0.0976 - accuracy: 0.9711 - val_loss: 0.0965 - val_accuracy: 0.9720
# Epoch 99/100
# 2500/2500 [==============================] - 4s 1ms/step - loss: 0.0972 - accuracy: 0.9709 - val_loss: 0.0978 - val_accuracy: 0.9696
# Epoch 100/100
# 2500/2500 [==============================] - 4s 1ms/step - loss: 0.0971 - accuracy: 0.9711 - val_loss: 0.0938 - val_accuracy: 0.9715

# %%
mlp_accuracy = mlp.evaluate(X_test, y_test, verbose=0)[1]
y_pred_mlp = (mlp.predict(X_test) > 0.5).astype(int)
# Out:
# 625/625 [==============================] - 0s 483us/step

# %%
print(f"MLP Accuracy: {mlp_accuracy}")
# Out:
# MLP Accuracy: 0.9715499877929688
